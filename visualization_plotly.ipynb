# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
def update_fig_layout(fig):

    plot_bg_color='rgba(255, 255,255, 0.8)'

    fig.update_layout(xaxis_title="",)
    fig.update_layout(xaxis_title="Dim1",  yaxis_title="Dim2",plot_bgcolor=plot_bg_color,)
    fig.update_yaxes( showline=True, linewidth=2, linecolor='white', mirror=True, showgrid=True, gridwidth=0.1, gridcolor='white', tickprefix='', ticksuffix=' ') 

    fig.update_xaxes(visible=True, showticklabels=True)
    fig.update_xaxes(showline=True, linewidth=1, linecolor='black')
    fig.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='rgb(230, 230, 230)')
    fig.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='rgb(230, 230, 230)')

    fig.update_layout(autosize=False, width=1000, height=500)

    return fig

# %%
pwd
# Out:
# '/home/javidan/Le_nuit_de_linfo'

# %%
ls
# Out:
# 6483002.zip  Code/  data/  figures/  visualization.ipynb

# %%
df = pd.read_excel('/home/javidan/Le_nuit_de_linfo/data/essd_ghg_data_2.xlsx', sheet_name='data')

# %%
df.drop(['region_ar6_6', 'region_ar6_10', 'region_ar6_10_short', 'region_ar6_22', 'region_ar6_dev', 'gwp100_ar5', 'gwp100_ar6', 'region_ar6_6_short'], axis=1, inplace=True)

# %%
df
# Out:
#          country  year    sector_title     subsector_title  gas         value
# 0          Aruba  1970       Buildings         Residential  CO2  5.452099e+02
# 1          Aruba  1970       Buildings         Residential  CH4  1.609412e-01
# 2          Aruba  1970       Buildings         Residential  N2O  4.802031e-03
# 3          Aruba  1970  Energy systems  Electricity & heat  CO2  3.091397e+04
# 4          Aruba  1970  Energy systems  Electricity & heat  CH4  4.155721e-01
# ...          ...   ...             ...                 ...  ...           ...
# 568336  Zimbabwe  2020        Industry              Metals  CO2  7.720092e+05
# 568337  Zimbabwe  2020        Industry    Other (industry)  CO2  9.523549e+05
# 568338  Zimbabwe  2020       Transport   Other (transport)  CO2  3.099450e+05
# 568339  Zimbabwe  2020       Transport               Rail   CO2  1.491236e+05
# 568340  Zimbabwe  2020       Transport                Road  CO2  2.236932e+06
#
# [568341 rows x 6 columns]

# %%
df['country'].value_counts()
# Out:
# France                                  5085
# Russian Federation                      5017
# Spain                                   4888
# United Kingdom                          4883
# Japan                                   4882
#                                         ...
# United States Minor Outlying Islands       1
# Pitcairn                                   1
# Bouvet Island                              1
# Cocos (Keeling) Islands                    1
# Christmas Island                           1
# Name: country, Length: 230, dtype: int64

# %%
fr_df = df[df['country'] == 'France']
fr_df.shape
# Out:
# (5085, 7)

# %%
fr_df[fr_df['year'] == 1970]['value'].sum()
# Out:
# 470736343.0424308

# %%
fr_df[fr_df['year'] == 2020]['value'].sum()
# Out:
# 279990676.0594466

# %%
tmp_df = df.groupby('year')['value'].sum().reset_index()

# %%
# tmp_df

# %%
fig = px.line(tmp_df, x='year', y='value', title='Line Plot', labels={'x': 'Years', 'y': 'Total Amount of Emission'}, markers=True)
fig = update_fig_layout(fig)
fig.show()

# %%
gdp_df = pd.read_csv('../data/GlobalGDP.csv')
gdp_df
# Out:
#             COUNTRY  GDP (BILLIONS) CODE
# 0       Afghanistan           21.71  AFG
# 1           Albania           13.40  ALB
# 2           Algeria          227.80  DZA
# 3    American Samoa            0.75  ASM
# 4           Andorra            4.80  AND
# ..              ...             ...  ...
# 217  Virgin Islands            5.08  VGB
# 218       West Bank            6.64  WBG
# 219           Yemen           45.45  YEM
# 220          Zambia           25.61  ZMB
# 221        Zimbabwe           13.74  ZWE
#
# [222 rows x 3 columns]

# %%
gdp_df[gdp_df['CODE'] == 'USA']
# Out:
#            COUNTRY  GDP (BILLIONS) CODE
# 211  United States         17420.0  USA

# %%
gdp_df[gdp_df['COUNTRY'].str.startswith('Un')]
# Out:
#                   COUNTRY  GDP (BILLIONS) CODE
# 209  United Arab Emirates           416.4  ARE
# 210        United Kingdom          2848.0  GBR
# 211         United States         17420.0  USA

# %%
df
# Out:
#         ISO   country region_ar6_6_short  year    sector_title  \
# 0       ABW     Aruba                LAM  1970       Buildings
# 1       ABW     Aruba                LAM  1970       Buildings
# 2       ABW     Aruba                LAM  1970       Buildings
# 3       ABW     Aruba                LAM  1970  Energy systems
# 4       ABW     Aruba                LAM  1970  Energy systems
# ...     ...       ...                ...   ...             ...
# 568336  ZWE  Zimbabwe                AFR  2020        Industry
# 568337  ZWE  Zimbabwe                AFR  2020        Industry
# 568338  ZWE  Zimbabwe                AFR  2020       Transport
# 568339  ZWE  Zimbabwe                AFR  2020       Transport
# 568340  ZWE  Zimbabwe                AFR  2020       Transport
#
#            subsector_title  gas         value
# 0              Residential  CO2  5.452099e+02
# 1              Residential  CH4  1.609412e-01
# 2              Residential  N2O  4.802031e-03
# ...

# %%
df = pd.merge(df, gdp_df, left_on='ISO', right_on='CODE',how='left')

# %%
df = df.dropna()

# %%
# df['CODE'].value_counts().reset_index()['index'].str.startswith('na')

# %%
df.shape
# Out:
# (549108, 10)

# %%
df
# Out:
#         ISO   country  year    sector_title     subsector_title  gas  \
# 0       ABW     Aruba  1970       Buildings         Residential  CO2
# 1       ABW     Aruba  1970       Buildings         Residential  CH4
# 2       ABW     Aruba  1970       Buildings         Residential  N2O
# 3       ABW     Aruba  1970  Energy systems  Electricity & heat  CO2
# 4       ABW     Aruba  1970  Energy systems  Electricity & heat  CH4
# ...     ...       ...   ...             ...                 ...  ...
# 569884  ZWE  Zimbabwe  2020        Industry              Metals  CO2
# 569885  ZWE  Zimbabwe  2020        Industry    Other (industry)  CO2
# 569886  ZWE  Zimbabwe  2020       Transport   Other (transport)  CO2
# 569887  ZWE  Zimbabwe  2020       Transport               Rail   CO2
# 569888  ZWE  Zimbabwe  2020       Transport                Road  CO2
#
#                value   COUNTRY  GDP (BILLIONS) CODE
# 0       5.452099e+02     Aruba            2.52  ABW
# ...

# %%
tmp_df = df.groupby(['country', 'ISO'])['value'].sum().reset_index()

# %%
tmp_df.shape
# Out:
# (205, 3)

# %%
tmp_df
# Out:
#             country  ISO         value
# 0       Afghanistan  AFG  2.070694e+08
# 1           Albania  ALB  2.671651e+08
# 2           Algeria  DZA  4.579985e+09
# 3    American Samoa  ASM  2.329360e+04
# 4            Angola  AGO  9.182738e+08
# ..              ...  ...           ...
# 200   Venezuela, RB  VEN  6.069670e+09
# 201         Vietnam  VNM  4.183563e+09
# 202     Yemen, Rep.  YEM  6.124914e+08
# 203          Zambia  ZMB  1.952035e+08
# 204        Zimbabwe  ZWE  6.421163e+08
#
# [205 rows x 3 columns]

# %%
tmp_df = pd.merge(tmp_df, gdp_df, left_on='ISO', right_on='CODE',how='left')

# %%
tmp_df
# Out:
#             country  ISO         value         COUNTRY  GDP (BILLIONS) CODE
# 0       Afghanistan  AFG  2.070694e+08     Afghanistan           21.71  AFG
# 1           Albania  ALB  2.671651e+08         Albania           13.40  ALB
# 2           Algeria  DZA  4.579985e+09         Algeria          227.80  DZA
# 3    American Samoa  ASM  2.329360e+04  American Samoa            0.75  ASM
# 4            Angola  AGO  9.182738e+08          Angola          131.40  AGO
# ..              ...  ...           ...             ...             ...  ...
# 201   Venezuela, RB  VEN  6.069670e+09       Venezuela          209.20  VEN
# 202         Vietnam  VNM  4.183563e+09         Vietnam          187.80  VNM
# 203     Yemen, Rep.  YEM  6.124914e+08           Yemen           45.45  YEM
# 204          Zambia  ZMB  1.952035e+08          Zambia           25.61  ZMB
# 205        Zimbabwe  ZWE  6.421163e+08        Zimbabwe           13.74  ZWE
#
# [206 rows x 6 columns]

# %%
data = dict(type='choropleth', 
            locations = tmp_df['ISO'], 
            z = tmp_df['value'], 
            text = tmp_df['country'])

# %%
layout = dict(title = 'Global GDP - hammer projection',
              geo = dict( projection = {'type':'hammer'},
                         showlakes = True, 
                         lakecolor = 'rgb(0,191,255)'))

# %%
import plotly.graph_objs as pg
import plotly.offline as po

x = pg.Figure(data = [data], 
              layout = layout, 
              animation_frame='Year',)
po.iplot(x)

# %%
tmp_df
# Out:
#             country  ISO         value
# 0       Afghanistan  AFG  2.070694e+08
# 1           Albania  ALB  2.671651e+08
# 2           Algeria  DZA  4.579985e+09
# 3    American Samoa  ASM  2.329360e+04
# 4            Angola  AGO  9.182738e+08
# ..              ...  ...           ...
# 200   Venezuela, RB  VEN  6.069670e+09
# 201         Vietnam  VNM  4.183563e+09
# 202     Yemen, Rep.  YEM  6.124914e+08
# 203          Zambia  ZMB  1.952035e+08
# 204        Zimbabwe  ZWE  6.421163e+08
#
# [205 rows x 3 columns]

# %%
usa_df = df[df['ISO'] == 'FRA']
usa_df
# Out:
#         ISO country  year sector_title                       subsector_title  \
# 181334  FRA  France  1970        AFOLU            Biomass burning (CH4, N2O)
# 181335  FRA  France  1970        AFOLU            Biomass burning (CH4, N2O)
# 181336  FRA  France  1970        AFOLU            Enteric Fermentation (CH4)
# 181337  FRA  France  1970        AFOLU  Managed soils and pasture (CO2, N2O)
# 181338  FRA  France  1970        AFOLU  Managed soils and pasture (CO2, N2O)
# ...     ...     ...   ...          ...                                   ...
# 186414  FRA  France  2020    Transport                     Domestic Aviation
# 186415  FRA  France  2020    Transport                       Inland Shipping
# 186416  FRA  France  2020    Transport                     Other (transport)
# 186417  FRA  France  2020    Transport                                 Rail
# 186418  FRA  France  2020    Transport                                  Road
#
#         gas         value
# ...

# %%
usa_df[usa_df['year'] == 1970]['value'].sum()
# Out:
# 470736343.0424308

# %%
usa_df[usa_df['year'] == 2020]['value'].sum()
# Out:
# 279990676.0594466

# %%
tmp_df = df.groupby(['country', 'ISO', 'year'])['value'].sum().reset_index()

# %%
last_df = tmp_df[tmp_df['year'] == 2020]
last_df['value'] = last_df['value'] + last_df['value'] * 0.40
last_df
# Out:
# /tmp/ipykernel_20601/394377423.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               country  ISO  year         value
# 50        Afghanistan  AFG  2020  1.672701e+07
# 101           Albania  ALB  2020  7.144344e+06
# 152           Algeria  DZA  2020  2.288627e+08
# 253            Angola  AGO  2020  3.151904e+07
# 304          Anguilla  AIA  2020  3.340289e+04
# ...               ...  ...   ...           ...
# 11064         Vietnam  VNM  2020  4.506954e+08
# 11215  Western Sahara  ESH  2020  2.693540e+05
# 11266     Yemen, Rep.  YEM  2020  1.444588e+07
# 11317          Zambia  ZMB  2020  1.050131e+07
# 11368        Zimbabwe  ZWE  2020  1.618202e+07
#
# [210 rows x 4 columns]

# %%
last_df
# Out:
#               country  ISO  year         value
# 50        Afghanistan  AFG  2020  1.433744e+07
# 101           Albania  ALB  2020  6.123723e+06
# 152           Algeria  DZA  2020  1.961680e+08
# 253            Angola  AGO  2020  2.701632e+07
# 304          Anguilla  AIA  2020  2.863105e+04
# ...               ...  ...   ...           ...
# 11064         Vietnam  VNM  2020  3.863104e+08
# 11215  Western Sahara  ESH  2020  2.308749e+05
# 11266     Yemen, Rep.  YEM  2020  1.238218e+07
# 11317          Zambia  ZMB  2020  9.001123e+06
# 11368        Zimbabwe  ZWE  2020  1.387030e+07
#
# [210 rows x 4 columns]

# %%
import plotly.express as px

# Assuming you already have the tmp_df_2 DataFrame for a specific year

# Set the desired color bar range based on your data
colorbar_min = 0  # Set based on your data
colorbar_max = 10000000000  # Set based on your data

# Create choropleth map
fig = px.choropleth(
    last_df,
    locations='ISO',
    color='value',
    hover_name='country',
    projection='hammer',
    color_continuous_scale='Viridis',
    title=f'Worldwide Gas Emission in Gt at Year 2030',

    range_color=[colorbar_min, colorbar_max]  # Set the color bar range
)
fig.update_layout(
title=dict(
    x=0.5,  # Set x to 0.5 to center horizontally
    y=0.9   # Set y to a value between 0 and 1 to adjust the vertical position
)
)


# Show the plot
# fig.show()
fig.write_image(f'map_robin.png')

# %%
tmp_df[(tmp_df['country'] == 'France') & (tmp_df['year'] == 1970)]
# Out:
#      country  ISO  year         value
# 3419  France  FRA  1970  4.707363e+08

# %%
tmp_df[(tmp_df['country'] == 'France') & (tmp_df['year'] == 2020)]
# Out:
#      country  ISO  year         value
# 3469  France  FRA  2020  2.799907e+08

# %%
years = tmp_df['year'].unique()
years
# Out:
# array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
#        1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016, 2017, 2018, 2019, 2020])

# %%
tmp_df_2 = tmp_df[tmp_df['year'] == 1970]
tmp_df_3 = tmp_df_2[tmp_df_2['country'] == 'France']
tmp_df_3['value'].sum()
# Out:
# 470736343.0424309

# %%
tmp_df_2 = tmp_df[tmp_df['year'] == 2020]
tmp_df_3 = tmp_df_2[tmp_df_2['country'] == 'France']
tmp_df_3['value'].sum()
# Out:
# 279990676.0594466

# %%
tmp_df_2 = tmp_df[tmp_df['year'] == 2020]

# %%
for year in years:
    tmp_df_2 = tmp_df[tmp_df['year'] == year]
    import plotly.graph_objs as go
    import plotly.offline as po
    import pandas as pd

    # Create choropleth data
    data = dict(type='choropleth', 
            locations = tmp_df_2['ISO'], 
            z = tmp_df_2['value'], 
            text = tmp_df_2['country'])
    
    layout = dict(
              geo = dict( projection = {'type':'hammer'},
                         showlakes = True, 
                         lakecolor = 'rgb(0,191,255)'))
    
    import plotly.graph_objs as pg
    import plotly.offline as po

    x = pg.Figure(data = [data], 
                layout = layout, 
                )
#     po.iplot(x)

    # Display the plot
    x.write_image(f'map_{year}.png')

# %%
tmp_df_2 = tmp_df[tmp_df['year'] == 1970]
import plotly.graph_objs as go
import plotly.offline as po
import pandas as pd

# Create choropleth data
data = dict(type='choropleth', 
        locations = tmp_df_2['ISO'], 
        z = tmp_df_2['value'], 
        text = tmp_df_2['country'])

layout = dict(
            geo = dict( projection = {'type':'hammer'},
                        showlakes = True, 
                        lakecolor = 'rgb(0,191,255)'))

import plotly.graph_objs as pg
import plotly.offline as po

x = pg.Figure(data = [data], 
            layout = layout, 
            )
po.iplot(x)

# Display the plot

# %%
tmp_df_2 = tmp_df[tmp_df['year'] == 2000]
import plotly.graph_objs as go
import plotly.offline as po
import pandas as pd

# Create choropleth data
data = dict(type='choropleth', 
        locations = tmp_df_2['ISO'], 
        z = tmp_df_2['value'], 
        text = tmp_df_2['country'])

layout = dict(
            geo = dict( projection = {'type':'hammer'},
                        showlakes = True, 
                        lakecolor = 'rgb(0,191,255)'))

import plotly.graph_objs as pg
import plotly.offline as po

x = pg.Figure(data = [data], 
            layout = layout, 
            )
po.iplot(x)

# Display the plot

# %%
import plotly.graph_objs as go
import plotly.offline as po
import pandas as pd

# %%
import plotly.express as px

# Assuming you already have the tmp_df_2 DataFrame for a specific year

# Set the desired color bar range based on your data
colorbar_min = 0  # Set based on your data
colorbar_max = 10000000000  # Set based on your data

for year in years:
    tmp_df_2 = tmp_df[tmp_df['year'] == year]
    # Create choropleth map
    fig = px.choropleth(
        tmp_df_2,
        locations='ISO',
        color='value',
        hover_name='country',
        projection='hammer',
        color_continuous_scale='Viridis',
        title=f'Worldwide Gas Emission in Gt at Year {year}',

        range_color=[colorbar_min, colorbar_max]  # Set the color bar range
    )
    fig.update_layout(
    title=dict(
        x=0.5,  # Set x to 0.5 to center horizontally
        y=0.9   # Set y to a value between 0 and 1 to adjust the vertical position
    )
)


    # Show the plot
    # fig.show()
    fig.write_image(f'map_{year}.png')

# %%
import os
import imageio

# Path to the directory containing your images
image_folder = '/home/javidan/Le_nuit_de_linfo/'

# List all files in the directory and sort based on numerical order in filenames
files = sorted([f for f in os.listdir(image_folder) if f.endswith('.png')], key=lambda x: int(''.join(filter(str.isdigit, x))))

# Create frames from the images
frames = []
for file in files:
    file_path = os.path.join(image_folder, file)
    frames.append(imageio.imread(file_path))

# Save the frames as a GIF

output_gif_path = f'figures/map_world.gif'

imageio.mimsave(output_gif_path, frames, duration=300)
# Out:
# /tmp/ipykernel_20601/569143230.py:14: DeprecationWarning:
#
# Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.

# %%
pip install imageio

# %%
for year in years:
    tmp_df_2 = tmp_df[tmp_df['year'] == year]


    # Create choropleth data
    data = dict(type='choropleth', 
            locations = tmp_df_2['ISO'], 
            z = tmp_df_2['value'], 
            text = tmp_df_2['country'])

    layout = dict(
                geo = dict( projection = {'type':'hammer'},
                            showlakes = True, 
                            lakecolor = 'rgb(0,191,255)'))

    import plotly.graph_objs as pg
    import plotly.offline as po

    x = pg.Figure(data = [data], 
                layout = layout, 
                )
    po.iplot(x)
    x.write_image(f'map_{year}.png')

# Display the plot
